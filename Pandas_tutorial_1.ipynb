# %% [markdown]
# # Pandas tutorial.
# - URL: https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/

# %% [markdown]
# #### Prepared by: Sagun Shakya
# - GITAM Institute of Science.

# %%
import pandas as pd

# %% [markdown]
# ## Creating a dataframe.

# %% [markdown]
# ### Using a dictionary:

# %%
data = dict()

data['apples'] = [0,1,2,3]
data['oranges'] = [9,4,3,5]

# %%
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#    apples  oranges
# 0       0        9
# 1       1        4
# 2       2        3
# 3       3        5

# %% [markdown]
# ## Creating our own index.

# %%
purchases = pd.DataFrame(data, index = ['Robert', "Sagun", 'Alice', 'Ben'])
print(purchases)
# Out:
#         apples  oranges
# Robert       0        9
# Sagun        1        4
# Alice        2        3
# Ben          3        5

# %% [markdown]
# ### **Loc**ating a person's orders using their name as a key.

# %%
purchases.loc['Sagun':'Ben']
# Out:
#        apples  oranges
# Sagun       1        4
# Alice       2        3
# Ben         3        5

# %%
purchases.iloc[1:3]
# Out:
#        apples  oranges
# Sagun       1        4
# Alice       2        3

# %% [markdown]
# ## Reading data from .csv files.
# - Make sue that the .csv file is stored inside the folder where your current .ipynb file is located.
# - If the .csv file is in another location, we can import os module and change the directory:
#     - import os
#     - os.chdir('**FIle Path**')

# %%
df = pd.read_csv('Toyota.csv')

#df = pd.read_csv('Toyota.csv', index_col = 0)
#To exclude the index column which is set into the dataframe by default.

# %% [markdown]
# ## Reading data from json files.

# %%
#df = pd.read_json('purchases.json')

# %% [markdown]
# ## Converting the file to a particular format.
# - After doing the task of data cleaning extensively, we can convert the newly created dataframe into a new file (.csv, .json, sql and so on).

# %%
#df.to_csv('purchases_new.csv')
#df.to_json('purchases_new.json')
#df.to_sql('purchases_new', con)

# %% [markdown]
# # DataFrame Operations.

# %% [markdown]
# #### We will use IMDB movies list as our dataframe.

# %%
movies = pd.read_csv('imdb.csv')

# %% [markdown]
# #### Checking few tuples for reference and better understanding of the dataset.

# %%
movies.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# 3                  22000.0                 23000.0     Christian Bale
# 4                    131.0                     NaN         Rob Walker
# 5                    475.0                   530.0    Samantha Morton
# 6                      0.0                  4000.0       James Franco
# 7                     15.0                   284.0       Donna Murphy
# 8                      0.0                 19000.0  Robert Downey Jr.
# 9                    282.0                 10000.0   Daniel Radcliffe
#
#    actor_1_facebook_likes        gross  \
# 0                  1000.0  760505847.0
# 1                 40000.0  309404152.0
# 2                 11000.0  200074175.0
# 3                 27000.0  448130642.0
# 4                   131.0          NaN
# 5                   640.0   73058679.0
# 6                 24000.0  336530303.0
# 7                   799.0  200807262.0
# 8                 26000.0  458991599.0
# 9                 25000.0  301956980.0
#
#                                               genres  ...  \
# 0                    Action|Adventure|Fantasy|Sci-Fi  ...
# 1                           Action|Adventure|Fantasy  ...
# 2                          Action|Adventure|Thriller  ...
# 3                                    Action|Thriller  ...
# 4                                        Documentary  ...
# 5                            Action|Adventure|Sci-Fi  ...
# 6                           Action|Adventure|Romance  ...
# 7  Adventure|Animation|Comedy|Family|Fantasy|Musi...  ...
# 8                            Action|Adventure|Sci-Fi  ...
# 9                   Adventure|Family|Fantasy|Mystery  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
# 5                738.0  English      USA           PG-13  263700000.0
# 6               1902.0  English      USA           PG-13  258000000.0
# 7                387.0  English      USA              PG  260000000.0
# 8               1117.0  English      USA           PG-13  250000000.0
# 9                973.0  English       UK              PG  250000000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
# 5      2012.0                  632.0        6.6          2.35
# 6      2007.0                11000.0        6.2          2.35
# 7      2010.0                  553.0        7.8          1.85
# 8      2015.0                21000.0        7.5          2.35
# 9      2009.0                11000.0        7.5          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
# 5                24000
# 6                    0
# 7                29000
# 8               118000
# 9                10000
#
# [10 rows x 28 columns]

# %% [markdown]
# ### Setting the movie_title as index column.

# %%
movies = pd.read_csv('imdb.csv', index_col = 'movie_title')
movies.head()

#For viewing the last 'n' rowns, we use .tail(n)
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
#
#                                                     num_critic_for_reviews  \
# movie_title
# Avatar                                                               723.0
# Pirates of the Caribbean: At World's End                             302.0
# Spectre                                                              602.0
# The Dark Knight Rises                                                813.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
#
#                                                     duration  \
# movie_title
# Avatar                                                 178.0
# Pirates of the Caribbean: At World's End               169.0
# Spectre                                                148.0
# The Dark Knight Rises                                  164.0
# Star Wars: Episode VII - The Force Awakens     ...       NaN
#
#                                                     director_facebook_likes  \
# movie_title
# Avatar                                                                  0.0
# Pirates of the Caribbean: At World's End                              563.0
# Spectre                                                                 0.0
# The Dark Knight Rises                                               22000.0
# Star Wars: Episode VII - The Force Awakens     ...                    131.0
#
#                                                     actor_3_facebook_likes  \
# movie_title
# Avatar                                                               855.0
# Pirates of the Caribbean: At World's End                            1000.0
# Spectre                                                              161.0
# The Dark Knight Rises                                              23000.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
#
#                                                         actor_2_name  \
# movie_title
# Avatar                                              Joel David Moore
# Pirates of the Caribbean: At World's End               Orlando Bloom
# Spectre                                                 Rory Kinnear
# The Dark Knight Rises                                 Christian Bale
# Star Wars: Episode VII - The Force Awakens     ...        Rob Walker
#
#                                                     actor_1_facebook_likes  \
# movie_title
# Avatar                                                              1000.0
# Pirates of the Caribbean: At World's End                           40000.0
# Spectre                                                            11000.0
# The Dark Knight Rises                                              27000.0
# Star Wars: Episode VII - The Force Awakens     ...                   131.0
#
#                                                           gross  \
# movie_title
# Avatar                                              760505847.0
# Pirates of the Caribbean: At World's End            309404152.0
# Spectre                                             200074175.0
# The Dark Knight Rises                               448130642.0
# Star Wars: Episode VII - The Force Awakens     ...          NaN
#
#                                                                              genres  \
# movie_title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
#
#                                                     ... num_user_for_reviews  \
# movie_title                                         ...
# Avatar                                              ...               3054.0
# Pirates of the Caribbean: At World's End            ...               1238.0
# Spectre                                             ...                994.0
# The Dark Knight Rises                               ...               2701.0
# Star Wars: Episode VII - The Force Awakens     ...  ...                  NaN
#
#                                                     language  country  \
# movie_title
# Avatar                                               English      USA
# Pirates of the Caribbean: At World's End             English      USA
# Spectre                                              English       UK
# The Dark Knight Rises                                English      USA
# Star Wars: Episode VII - The Force Awakens     ...       NaN      NaN
#
#                                                    content_rating  \
# movie_title
# Avatar                                                      PG-13
# Pirates of the Caribbean: At World's End                    PG-13
# Spectre                                                     PG-13
# The Dark Knight Rises                                       PG-13
# Star Wars: Episode VII - The Force Awakens     ...            NaN
#
#                                                          budget title_year  \
# movie_title
# Avatar                                              237000000.0     2009.0
# Pirates of the Caribbean: At World's End            300000000.0     2007.0
# Spectre                                             245000000.0     2015.0
# The Dark Knight Rises                               250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens     ...          NaN        NaN
#
#                                                    actor_2_facebook_likes  \
# movie_title
# Avatar                                                              936.0
# Pirates of the Caribbean: At World's End                           5000.0
# Spectre                                                             393.0
# The Dark Knight Rises                                             23000.0
# Star Wars: Episode VII - The Force Awakens     ...                   12.0
#
#                                                     imdb_score aspect_ratio  \
# movie_title
# Avatar                                                     7.9         1.78
# Pirates of the Caribbean: At World's End                   7.1         2.35
# Spectre                                                    6.8         2.35
# The Dark Knight Rises                                      8.5         2.35
# Star Wars: Episode VII - The Force Awakens     ...         7.1          NaN
#
#                                                    movie_facebook_likes
# movie_title
# Avatar                                                            33000
# Pirates of the Caribbean: At World's End                              0
# Spectre                                                           85000
# The Dark Knight Rises                                            164000
# Star Wars: Episode VII - The Force Awakens     ...                    0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Getting to know our data a little better.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5043 entries, Avatar  to My Date with Drew
# Data columns (total 27 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# plot_keywords                4890 non-null object
# movie_imdb_link              5043 non-null object
# num_user_for_reviews         5022 non-null float64
# language                     5031 non-null object
# country                      5038 non-null object
# content_rating               4740 non-null object
# budget                       4551 non-null float64
# title_year                   4935 non-null float64
# actor_2_facebook_likes       5030 non-null float64
# imdb_score                   5043 non-null float64
# aspect_ratio                 4714 non-null float64
# movie_facebook_likes         5043 non-null int64
# dtypes: float64(13), int64(3), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking the dimension of our dataframe.

# %%
movies.shape
# Out:
# (5043, 27)

# %% [markdown]
# ## Handling duplicate rows.
#
# - If two rows are the same, pandas will drop the second row and **keep** the first row.

# %%
movies.drop_duplicates()
# Out:
#                                                     color      director_name  \
# movie_title
# Avatar                                              Color      James Cameron
# Pirates of the Caribbean: At World's End            Color     Gore Verbinski
# Spectre                                             Color         Sam Mendes
# The Dark Knight Rises                               Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens     ...    NaN        Doug Walker
# ...                                                   ...                ...
# Signed Sealed Delivered                             Color        Scott Smith
# The Following                                       Color                NaN
# A Plague So Pleasant                                Color   Benjamin Roberds
# Shanghai Calling                                    Color        Daniel Hsia
# My Date with Drew                                   Color           Jon Gunn
#
#                                                     num_critic_for_reviews  \
# movie_title
# Avatar                                                               723.0
# Pirates of the Caribbean: At World's End                             302.0
# Spectre                                                              602.0
# The Dark Knight Rises                                                813.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
# ...                                                                    ...
# Signed Sealed Delivered                                                1.0
# The Following                                                         43.0
# A Plague So Pleasant                                                  13.0
# Shanghai Calling                                                      14.0
# My Date with Drew                                                     43.0
#
#                                                     duration  \
# movie_title
# Avatar                                                 178.0
# Pirates of the Caribbean: At World's End               169.0
# Spectre                                                148.0
# The Dark Knight Rises                                  164.0
# Star Wars: Episode VII - The Force Awakens     ...       NaN
# ...                                                      ...
# Signed Sealed Delivered                                 87.0
# The Following                                           43.0
# A Plague So Pleasant                                    76.0
# Shanghai Calling                                       100.0
# My Date with Drew                                       90.0
#
#                                                     director_facebook_likes  \
# movie_title
# Avatar                                                                  0.0
# Pirates of the Caribbean: At World's End                              563.0
# Spectre                                                                 0.0
# The Dark Knight Rises                                               22000.0
# Star Wars: Episode VII - The Force Awakens     ...                    131.0
# ...                                                                     ...
# Signed Sealed Delivered                                                 2.0
# The Following                                                           NaN
# A Plague So Pleasant                                                    0.0
# Shanghai Calling                                                        0.0
# My Date with Drew                                                      16.0
#
#                                                     actor_3_facebook_likes  \
# movie_title
# Avatar                                                               855.0
# Pirates of the Caribbean: At World's End                            1000.0
# Spectre                                                              161.0
# The Dark Knight Rises                                              23000.0
# Star Wars: Episode VII - The Force Awakens     ...                     NaN
# ...                                                                    ...
# Signed Sealed Delivered                                              318.0
# The Following                                                        319.0
# A Plague So Pleasant                                                   0.0
# Shanghai Calling                                                     489.0
# My Date with Drew                                                     16.0
#
#                                                         actor_2_name  \
# movie_title
# Avatar                                              Joel David Moore
# Pirates of the Caribbean: At World's End               Orlando Bloom
# Spectre                                                 Rory Kinnear
# The Dark Knight Rises                                 Christian Bale
# Star Wars: Episode VII - The Force Awakens     ...        Rob Walker
# ...                                                              ...
# Signed Sealed Delivered                                Daphne Zuniga
# The Following                                          Valorie Curry
# A Plague So Pleasant                                   Maxwell Moody
# Shanghai Calling                                       Daniel Henney
# My Date with Drew                                   Brian Herzlinger
#
#                                                     actor_1_facebook_likes  \
# movie_title
# Avatar                                                              1000.0
# Pirates of the Caribbean: At World's End                           40000.0
# Spectre                                                            11000.0
# The Dark Knight Rises                                              27000.0
# Star Wars: Episode VII - The Force Awakens     ...                   131.0
# ...                                                                    ...
# Signed Sealed Delivered                                              637.0
# The Following                                                        841.0
# A Plague So Pleasant                                                   0.0
# Shanghai Calling                                                     946.0
# My Date with Drew                                                     86.0
#
#                                                           gross  \
# movie_title
# Avatar                                              760505847.0
# Pirates of the Caribbean: At World's End            309404152.0
# Spectre                                             200074175.0
# The Dark Knight Rises                               448130642.0
# Star Wars: Episode VII - The Force Awakens     ...          NaN
# ...                                                         ...
# Signed Sealed Delivered                                     NaN
# The Following                                               NaN
# A Plague So Pleasant                                        NaN
# Shanghai Calling                                        10443.0
# My Date with Drew                                       85222.0
#
#                                                                              genres  \
# movie_title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
# ...                                                                             ...
# Signed Sealed Delivered                                                Comedy|Drama
# The Following                                          Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                          Drama|Horror|Thriller
# Shanghai Calling                                               Comedy|Drama|Romance
# My Date with Drew                                                       Documentary
#
#                                                     ... num_user_for_reviews  \
# movie_title                                         ...
# Avatar                                              ...               3054.0
# Pirates of the Caribbean: At World's End            ...               1238.0
# Spectre                                             ...                994.0
# The Dark Knight Rises                               ...               2701.0
# Star Wars: Episode VII - The Force Awakens     ...  ...                  NaN
# ...                                                 ...                  ...
# Signed Sealed Delivered                             ...                  6.0
# The Following                                       ...                359.0
# A Plague So Pleasant                                ...                  3.0
# Shanghai Calling                                    ...                  9.0
# My Date with Drew                                   ...                 84.0
#
#                                                     language  country  \
# movie_title
# Avatar                                               English      USA
# Pirates of the Caribbean: At World's End             English      USA
# Spectre                                              English       UK
# The Dark Knight Rises                                English      USA
# Star Wars: Episode VII - The Force Awakens     ...       NaN      NaN
# ...                                                      ...      ...
# Signed Sealed Delivered                              English   Canada
# The Following                                        English      USA
# A Plague So Pleasant                                 English      USA
# Shanghai Calling                                     English      USA
# My Date with Drew                                    English      USA
#
#                                                    content_rating  \
# movie_title
# Avatar                                                      PG-13
# Pirates of the Caribbean: At World's End                    PG-13
# Spectre                                                     PG-13
# The Dark Knight Rises                                       PG-13
# Star Wars: Episode VII - The Force Awakens     ...            NaN
# ...                                                           ...
# Signed Sealed Delivered                                       NaN
# The Following                                               TV-14
# A Plague So Pleasant                                          NaN
# Shanghai Calling                                            PG-13
# My Date with Drew                                              PG
#
#                                                          budget title_year  \
# movie_title
# Avatar                                              237000000.0     2009.0
# Pirates of the Caribbean: At World's End            300000000.0     2007.0
# Spectre                                             245000000.0     2015.0
# The Dark Knight Rises                               250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens     ...          NaN        NaN
# ...                                                         ...        ...
# Signed Sealed Delivered                                     NaN     2013.0
# The Following                                               NaN        NaN
# A Plague So Pleasant                                     1400.0     2013.0
# Shanghai Calling                                            NaN     2012.0
# My Date with Drew                                        1100.0     2004.0
#
#                                                    actor_2_facebook_likes  \
# movie_title
# Avatar                                                              936.0
# Pirates of the Caribbean: At World's End                           5000.0
# Spectre                                                             393.0
# The Dark Knight Rises                                             23000.0
# Star Wars: Episode VII - The Force Awakens     ...                   12.0
# ...                                                                   ...
# Signed Sealed Delivered                                             470.0
# The Following                                                       593.0
# A Plague So Pleasant                                                  0.0
# Shanghai Calling                                                    719.0
# My Date with Drew                                                    23.0
#
#                                                     imdb_score aspect_ratio  \
# movie_title
# Avatar                                                     7.9         1.78
# Pirates of the Caribbean: At World's End                   7.1         2.35
# Spectre                                                    6.8         2.35
# The Dark Knight Rises                                      8.5         2.35
# Star Wars: Episode VII - The Force Awakens     ...         7.1          NaN
# ...                                                        ...          ...
# Signed Sealed Delivered                                    7.7          NaN
# The Following                                              7.5        16.00
# A Plague So Pleasant                                       6.3          NaN
# Shanghai Calling                                           6.3         2.35
# My Date with Drew                                          6.6         1.85
#
#                                                    movie_facebook_likes
# movie_title
# Avatar                                                            33000
# Pirates of the Caribbean: At World's End                              0
# Spectre                                                           85000
# The Dark Knight Rises                                            164000
# Star Wars: Episode VII - The Force Awakens     ...                    0
# ...                                                                 ...
# Signed Sealed Delivered                                              84
# The Following                                                     32000
# A Plague So Pleasant                                                 16
# Shanghai Calling                                                    660
# My Date with Drew                                                   456
#
# [4998 rows x 27 columns]

# %%
movies.shape
# Out:
# (5043, 27)

# %% [markdown]
# #### The dimension remains unaffected. This means there are no duplicate rows.

# %% [markdown]
# ## Viewing the column names of the dataframe.

# %%
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Renaming the column name.
# - from 'actor_1_name' to 'primary_actor'.
# - from 'actor_2_name' to 'secondary_actor'.

# %%
movies.rename(columns = { 'actor_1_name' : 'primary_actor',  'actor_2_name' : 'secondary_actor'}, inplace = True)
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'secondary_actor',
#        'actor_1_facebook_likes', 'gross', 'genres', 'primary_actor',
#        'num_voted_users', 'cast_total_facebook_likes', 'actor_3_name',
#        'facenumber_in_poster', 'plot_keywords', 'movie_imdb_link',
#        'num_user_for_reviews', 'language', 'country', 'content_rating',
#        'budget', 'title_year', 'actor_2_facebook_likes', 'imdb_score',
#        'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# ## Working out the missing values.
# - Two ways to deal with null values:
#     - Eliminating the whole row/column containing the null value.
#     - Filling in the void with a non - null value (a technique called __imputation__).

# %%
 movies.isnull()
# Out:
#                                                     color  director_name  \
# movie_title
# Avatar                                              False          False
# Pirates of the Caribbean: At World's End            False          False
# Spectre                                             False          False
# The Dark Knight Rises                               False          False
# Star Wars: Episode VII - The Force Awakens     ...   True          False
# ...                                                   ...            ...
# Signed Sealed Delivered                             False          False
# The Following                                       False           True
# A Plague So Pleasant                                False          False
# Shanghai Calling                                    False          False
# My Date with Drew                                   False          False
#
#                                                     num_critic_for_reviews  \
# movie_title
# Avatar                                                               False
# Pirates of the Caribbean: At World's End                             False
# Spectre                                                              False
# The Dark Knight Rises                                                False
# Star Wars: Episode VII - The Force Awakens     ...                    True
# ...                                                                    ...
# Signed Sealed Delivered                                              False
# The Following                                                        False
# A Plague So Pleasant                                                 False
# Shanghai Calling                                                     False
# My Date with Drew                                                    False
#
#                                                     duration  \
# movie_title
# Avatar                                                 False
# Pirates of the Caribbean: At World's End               False
# Spectre                                                False
# The Dark Knight Rises                                  False
# Star Wars: Episode VII - The Force Awakens     ...      True
# ...                                                      ...
# Signed Sealed Delivered                                False
# The Following                                          False
# A Plague So Pleasant                                   False
# Shanghai Calling                                       False
# My Date with Drew                                      False
#
#                                                     director_facebook_likes  \
# movie_title
# Avatar                                                                False
# Pirates of the Caribbean: At World's End                              False
# Spectre                                                               False
# The Dark Knight Rises                                                 False
# Star Wars: Episode VII - The Force Awakens     ...                    False
# ...                                                                     ...
# Signed Sealed Delivered                                               False
# The Following                                                          True
# A Plague So Pleasant                                                  False
# Shanghai Calling                                                      False
# My Date with Drew                                                     False
#
#                                                     actor_3_facebook_likes  \
# movie_title
# Avatar                                                               False
# Pirates of the Caribbean: At World's End                             False
# Spectre                                                              False
# The Dark Knight Rises                                                False
# Star Wars: Episode VII - The Force Awakens     ...                    True
# ...                                                                    ...
# Signed Sealed Delivered                                              False
# The Following                                                        False
# A Plague So Pleasant                                                 False
# Shanghai Calling                                                     False
# My Date with Drew                                                    False
#
#                                                     secondary_actor  \
# movie_title
# Avatar                                                        False
# Pirates of the Caribbean: At World's End                      False
# Spectre                                                       False
# The Dark Knight Rises                                         False
# Star Wars: Episode VII - The Force Awakens     ...            False
# ...                                                             ...
# Signed Sealed Delivered                                       False
# The Following                                                 False
# A Plague So Pleasant                                          False
# Shanghai Calling                                              False
# My Date with Drew                                             False
#
#                                                     actor_1_facebook_likes  \
# movie_title
# Avatar                                                               False
# Pirates of the Caribbean: At World's End                             False
# Spectre                                                              False
# The Dark Knight Rises                                                False
# Star Wars: Episode VII - The Force Awakens     ...                   False
# ...                                                                    ...
# Signed Sealed Delivered                                              False
# The Following                                                        False
# A Plague So Pleasant                                                 False
# Shanghai Calling                                                     False
# My Date with Drew                                                    False
#
#                                                     gross  genres  ...  \
# movie_title                                                        ...
# Avatar                                              False   False  ...
# Pirates of the Caribbean: At World's End            False   False  ...
# Spectre                                             False   False  ...
# The Dark Knight Rises                               False   False  ...
# Star Wars: Episode VII - The Force Awakens     ...   True   False  ...
# ...                                                   ...     ...  ...
# Signed Sealed Delivered                              True   False  ...
# The Following                                        True   False  ...
# A Plague So Pleasant                                 True   False  ...
# Shanghai Calling                                    False   False  ...
# My Date with Drew                                   False   False  ...
#
#                                                     num_user_for_reviews  \
# movie_title
# Avatar                                                             False
# Pirates of the Caribbean: At World's End                           False
# Spectre                                                            False
# The Dark Knight Rises                                              False
# Star Wars: Episode VII - The Force Awakens     ...                  True
# ...                                                                  ...
# Signed Sealed Delivered                                            False
# The Following                                                      False
# A Plague So Pleasant                                               False
# Shanghai Calling                                                   False
# My Date with Drew                                                  False
#
#                                                     language  country  \
# movie_title
# Avatar                                                 False    False
# Pirates of the Caribbean: At World's End               False    False
# Spectre                                                False    False
# The Dark Knight Rises                                  False    False
# Star Wars: Episode VII - The Force Awakens     ...      True     True
# ...                                                      ...      ...
# Signed Sealed Delivered                                False    False
# The Following                                          False    False
# A Plague So Pleasant                                   False    False
# Shanghai Calling                                       False    False
# My Date with Drew                                      False    False
#
#                                                     content_rating  budget  \
# movie_title
# Avatar                                                       False   False
# Pirates of the Caribbean: At World's End                     False   False
# Spectre                                                      False   False
# The Dark Knight Rises                                        False   False
# Star Wars: Episode VII - The Force Awakens     ...            True    True
# ...                                                            ...     ...
# Signed Sealed Delivered                                       True    True
# The Following                                                False    True
# A Plague So Pleasant                                          True   False
# Shanghai Calling                                             False    True
# My Date with Drew                                            False   False
#
#                                                     title_year  \
# movie_title
# Avatar                                                   False
# Pirates of the Caribbean: At World's End                 False
# Spectre                                                  False
# The Dark Knight Rises                                    False
# Star Wars: Episode VII - The Force Awakens     ...        True
# ...                                                        ...
# Signed Sealed Delivered                                  False
# The Following                                             True
# A Plague So Pleasant                                     False
# Shanghai Calling                                         False
# My Date with Drew                                        False
#
#                                                     actor_2_facebook_likes  \
# movie_title
# Avatar                                                               False
# Pirates of the Caribbean: At World's End                             False
# Spectre                                                              False
# The Dark Knight Rises                                                False
# Star Wars: Episode VII - The Force Awakens     ...                   False
# ...                                                                    ...
# Signed Sealed Delivered                                              False
# The Following                                                        False
# A Plague So Pleasant                                                 False
# Shanghai Calling                                                     False
# My Date with Drew                                                    False
#
#                                                     imdb_score  aspect_ratio  \
# movie_title
# Avatar                                                   False         False
# Pirates of the Caribbean: At World's End                 False         False
# Spectre                                                  False         False
# The Dark Knight Rises                                    False         False
# Star Wars: Episode VII - The Force Awakens     ...       False          True
# ...                                                        ...           ...
# Signed Sealed Delivered                                  False          True
# The Following                                            False         False
# A Plague So Pleasant                                     False          True
# Shanghai Calling                                         False         False
# My Date with Drew                                        False         False
#
#                                                     movie_facebook_likes
# movie_title
# Avatar                                                             False
# Pirates of the Caribbean: At World's End                           False
# Spectre                                                            False
# The Dark Knight Rises                                              False
# Star Wars: Episode VII - The Force Awakens     ...                 False
# ...                                                                  ...
# Signed Sealed Delivered                                            False
# The Following                                                      False
# A Plague So Pleasant                                               False
# Shanghai Calling                                                   False
# My Date with Drew                                                  False
#
# [5043 rows x 27 columns]

# %%
# A more concise way.
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# secondary_actor               13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# primary_actor                  7
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# #### Dropping rows is useful when the null values exist in small numbers.
# - movies.dropna()
# - movies.dropna(axis = 1)  (For dropping column.)

# %% [markdown]
# ## Imputation
# - Filling in the null value with mean or a median value.

# %%
grossing = movies['gross']       #Dictionary key - value pairs.

grossing.head()
# Out:
# movie_title
# Avatar                                                     760505847.0
# Pirates of the Caribbean: At World's End                   309404152.0
# Spectre                                                    200074175.0
# The Dark Knight Rises                                      448130642.0
# Star Wars: Episode VII - The Force Awakens                         NaN
# Name: gross, dtype: float64

# %%
grossing.isnull().sum()
# Out:
# 884

# %%
grossing_mean = grossing.mean()
print(round(grossing_mean, 2))
# Out:
# 48468407.53

# %% [markdown]
# ### Filling the null values with the mean.

# %%
grossing.fillna(grossing_mean, inplace=True)

# %%
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# secondary_actor               13
# actor_1_facebook_likes         7
# gross                          0
# genres                         0
# primary_actor                  7
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# ### Imputing an entire column with the same value like this is a basic example.

# %% [markdown]
# ### Better to try a more granular approach.
# - Find the mean of the revenue generated in each genre individually and impute the nulls in each genre with that genre's mean.

# %% [markdown]
# ## Statistical summary of the entire dataframe using describe().

# %%
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  5.043000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.216318e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                133.000000              614.000000  8.460992e+06
# 50%                371.500000              988.000000  3.743230e+07
# 75%                636.000000            11000.000000  5.135707e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     5.043000e+03                5043.000000           5030.000000
# mean      8.366816e+04                9699.063851              1.371173
# std       1.384853e+05               18163.799124              2.013576
# min       5.000000e+00                   0.000000              0.000000
# 25%       8.593500e+03                1411.000000              0.000000
# 50%       3.435900e+04                3090.000000              1.000000
# 75%       9.630900e+04               13756.500000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           5022.000000  4.551000e+03  4935.000000
# mean             272.770808  3.975262e+07  2002.470517
# std              377.982886  2.061149e+08    12.474599
# min                1.000000  2.180000e+02  1916.000000
# 25%               65.000000  6.000000e+06  1999.000000
# 50%              156.000000  2.000000e+07  2005.000000
# 75%              326.000000  4.500000e+07  2011.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  movie_facebook_likes
# count             5030.000000  5043.000000   4714.000000           5043.000000
# mean              1651.754473     6.442138      2.220403           7525.964505
# std               4042.438863     1.125116      1.385113          19320.445110
# min                  0.000000     1.600000      1.180000              0.000000
# 25%                281.000000     5.800000      1.850000              0.000000
# 50%                595.000000     6.600000      2.350000            166.000000
# 75%                918.000000     7.200000      2.350000           3000.000000
# max             137000.000000     9.500000     16.000000         349000.000000

# %%
movies['gross'].describe()
# Out:
# count    5.043000e+03
# mean     4.846841e+07
# std      6.216318e+07
# min      1.620000e+02
# 25%      8.460992e+06
# 50%      3.743230e+07
# 75%      5.135707e+07
# max      7.605058e+08
# Name: gross, dtype: float64

# %%
movies['genres'].describe()
# Out:
# count      5043
# unique      914
# top       Drama
# freq        236
# Name: genres, dtype: object

# %%
movies['genres'].value_counts().head(7)
# Out:
# Drama                   236
# Comedy                  209
# Comedy|Drama            191
# Comedy|Drama|Romance    187
# Comedy|Romance          158
# Drama|Romance           152
# Crime|Drama|Thriller    101
# Name: genres, dtype: int64

# %% [markdown]
# ## Relationship between continuous variables (correlation).

# %%
movies.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.258486
# duration                                 0.258486  1.000000
# director_facebook_likes                  0.180674  0.173296
# actor_3_facebook_likes                   0.271646  0.123558
# actor_1_facebook_likes                   0.190016  0.088449
# gross                                    0.442045  0.204998
# num_voted_users                          0.624943  0.314765
# cast_total_facebook_likes                0.263203  0.123074
# facenumber_in_poster                    -0.033897  0.013469
# num_user_for_reviews                     0.609387  0.328403
# budget                                   0.119994  0.074276
# title_year                               0.275707 -0.135038
# actor_2_facebook_likes                   0.282306  0.131673
# imdb_score                               0.305303  0.261662
# aspect_ratio                            -0.049786 -0.090071
# movie_facebook_likes                     0.683176  0.196605
#
#                            director_facebook_likes  actor_3_facebook_likes  \
# num_critic_for_reviews                    0.180674                0.271646
# duration                                  0.173296                0.123558
# director_facebook_likes                   1.000000                0.120199
# actor_3_facebook_likes                    0.120199                1.000000
# actor_1_facebook_likes                    0.090723                0.249927
# gross                                     0.139254                0.304510
# num_voted_users                           0.297057                0.287239
# cast_total_facebook_likes                 0.119549                0.473920
# facenumber_in_poster                     -0.041268                0.099368
# num_user_for_reviews                      0.221890                0.230189
# budget                                    0.021090                0.047451
# title_year                               -0.063820                0.096137
# actor_2_facebook_likes                    0.119601                0.559662
# imdb_score                                0.170802                0.052633
# aspect_ratio                              0.001642               -0.003366
# movie_facebook_likes                      0.162048                0.278844
#
#                            actor_1_facebook_likes     gross  num_voted_users  \
# num_critic_for_reviews                   0.190016  0.442045         0.624943
# duration                                 0.088449  0.204998         0.314765
# director_facebook_likes                  0.090723  0.139254         0.297057
# actor_3_facebook_likes                   0.249927  0.304510         0.287239
# actor_1_facebook_likes                   1.000000  0.140615         0.192804
# gross                                    0.140615  1.000000         0.615385
# num_voted_users                          0.192804  0.615385         1.000000
# cast_total_facebook_likes                0.951661  0.229040         0.265911
# facenumber_in_poster                     0.072257 -0.025559        -0.026998
# num_user_for_reviews                     0.145461  0.538480         0.798406
# budget                                   0.022639  0.102836         0.079621
# title_year                               0.086873  0.022626         0.007397
# actor_2_facebook_likes                   0.390487  0.258188         0.270790
# imdb_score                               0.076099  0.168169         0.410965
# aspect_ratio                            -0.020049  0.014918        -0.014761
# movie_facebook_likes                     0.135348  0.369427         0.537924
#
#                            cast_total_facebook_likes  facenumber_in_poster  \
# num_critic_for_reviews                      0.263203             -0.033897
# duration                                    0.123074              0.013469
# director_facebook_likes                     0.119549             -0.041268
# actor_3_facebook_likes                      0.473920              0.099368
# actor_1_facebook_likes                      0.951661              0.072257
# gross                                       0.229040             -0.025559
# num_voted_users                             0.265911             -0.026998
# cast_total_facebook_likes                   1.000000              0.091475
# facenumber_in_poster                        0.091475              1.000000
# num_user_for_reviews                        0.206923             -0.069018
# budget                                      0.036557             -0.019559
# title_year                                  0.109971              0.061504
# actor_2_facebook_likes                      0.628404              0.071228
# imdb_score                                  0.085787             -0.062958
# aspect_ratio                               -0.017885              0.013713
# movie_facebook_likes                        0.209786              0.008918
#
#                            num_user_for_reviews    budget  title_year  \
# num_critic_for_reviews                 0.609387  0.119994    0.275707
# duration                               0.328403  0.074276   -0.135038
# director_facebook_likes                0.221890  0.021090   -0.063820
# actor_3_facebook_likes                 0.230189  0.047451    0.096137
# actor_1_facebook_likes                 0.145461  0.022639    0.086873
# gross                                  0.538480  0.102836    0.022626
# num_voted_users                        0.798406  0.079621    0.007397
# cast_total_facebook_likes              0.206923  0.036557    0.109971
# facenumber_in_poster                  -0.069018 -0.019559    0.061504
# num_user_for_reviews                   1.000000  0.084292   -0.003147
# budget                                 0.084292  1.000000    0.045726
# title_year                            -0.003147  0.045726    1.000000
# actor_2_facebook_likes                 0.219496  0.044236    0.101890
# imdb_score                             0.292475  0.030688   -0.209167
# aspect_ratio                          -0.024719  0.006598    0.159973
# movie_facebook_likes                   0.400594  0.062039    0.218678
#
#                            actor_2_facebook_likes  imdb_score  aspect_ratio  \
# num_critic_for_reviews                   0.282306    0.305303     -0.049786
# duration                                 0.131673    0.261662     -0.090071
# director_facebook_likes                  0.119601    0.170802      0.001642
# actor_3_facebook_likes                   0.559662    0.052633     -0.003366
# actor_1_facebook_likes                   0.390487    0.076099     -0.020049
# gross                                    0.258188    0.168169      0.014918
# num_voted_users                          0.270790    0.410965     -0.014761
# cast_total_facebook_likes                0.628404    0.085787     -0.017885
# facenumber_in_poster                     0.071228   -0.062958      0.013713
# num_user_for_reviews                     0.219496    0.292475     -0.024719
# budget                                   0.044236    0.030688      0.006598
# title_year                               0.101890   -0.209167      0.159973
# actor_2_facebook_likes                   1.000000    0.083808     -0.007783
# imdb_score                               0.083808    1.000000      0.059445
# aspect_ratio                            -0.007783    0.059445      1.000000
# movie_facebook_likes                     0.243487    0.247049      0.025737
#
#                            movie_facebook_likes
# num_critic_for_reviews                 0.683176
# duration                               0.196605
# director_facebook_likes                0.162048
# actor_3_facebook_likes                 0.278844
# actor_1_facebook_likes                 0.135348
# gross                                  0.369427
# num_voted_users                        0.537924
# cast_total_facebook_likes              0.209786
# facenumber_in_poster                   0.008918
# num_user_for_reviews                   0.400594
# budget                                 0.062039
# title_year                             0.218678
# actor_2_facebook_likes                 0.243487
# imdb_score                             0.247049
# aspect_ratio                           0.025737
# movie_facebook_likes                   1.000000

# %% [markdown]
# ## DataFrame slicing, selecting, extracting.

# %% [markdown]
# ### Type of attribute.

# %%
genre = movies['genres']
type(genre)                                       # Series.
# Out:
# pandas.core.series.Series

# %%
genre_1 = movies[['genres']]                    #Should be a list.
type(genre_1)                                     #DataFrame.
# Out:
# pandas.core.frame.DataFrame

# %%
sub = movies[['genres','gross','imdb_score']]
type(sub)                                          #DataFrame.
# Out:
# pandas.core.frame.DataFrame

# %%
sub.head()
# Out:
#                                                                              genres  \
# movie_title
# Avatar                                              Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End                   Action|Adventure|Fantasy
# Spectre                                                   Action|Adventure|Thriller
# The Dark Knight Rises                                               Action|Thriller
# Star Wars: Episode VII - The Force Awakens     ...                      Documentary
#
#                                                            gross  imdb_score
# movie_title
# Avatar                                              7.605058e+08         7.9
# Pirates of the Caribbean: At World's End            3.094042e+08         7.1
# Spectre                                             2.000742e+08         6.8
# The Dark Knight Rises                               4.481306e+08         8.5
# Star Wars: Episode VII - The Force Awakens     ...  4.846841e+07         7.1

# %% [markdown]
# ## Getting data by row.
# -Two Options:
#     - .loc = locates by name.
#     - .iloc = locates by numerical index.

# %%
ava = movies.iloc[1]
ava
# Out:
# color                                                                    Color
# director_name                                                   Gore Verbinski
# num_critic_for_reviews                                                     302
# duration                                                                   169
# director_facebook_likes                                                    563
# actor_3_facebook_likes                                                    1000
# actor_2_name                                                     Orlando Bloom
# actor_1_facebook_likes                                                   40000
# gross                                                              3.09404e+08
# genres                                                Action|Adventure|Fantasy
# actor_1_name                                                       Johnny Depp
# num_voted_users                                                         471220
# cast_total_facebook_likes                                                48350
# actor_3_name                                                    Jack Davenport
# facenumber_in_poster                                                         0
# plot_keywords                goddess|marriage ceremony|marriage proposal|pi...
# movie_imdb_link              http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# num_user_for_reviews                                                      1238
# language                                                               English
# country                                                                    USA
# content_rating                                                           PG-13
# budget                                                                   3e+08
# title_year                                                                2007
# actor_2_facebook_likes                                                    5000
# imdb_score                                                                 7.1
# aspect_ratio                                                              2.35
# movie_facebook_likes                                                         0
# Name: Pirates of the Caribbean: At World's End , dtype: object

# %%
sub = movies[['title_year', 'actor_1_name','genres', 'imdb_score', 'gross']]
sub.iloc[5:10]
# Out:
#                                          title_year     actor_1_name  \
# movie_title
# John Carter                                  2012.0     Daryl Sabara
# Spider-Man 3                                 2007.0     J.K. Simmons
# Tangled                                      2010.0     Brad Garrett
# Avengers: Age of Ultron                      2015.0  Chris Hemsworth
# Harry Potter and the Half-Blood Prince       2009.0     Alan Rickman
#
#                                                                                     genres  \
# movie_title
# John Carter                                                        Action|Adventure|Sci-Fi
# Spider-Man 3                                                      Action|Adventure|Romance
# Tangled                                  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# Avengers: Age of Ultron                                            Action|Adventure|Sci-Fi
# Harry Potter and the Half-Blood Prince                    Adventure|Family|Fantasy|Mystery
#
#                                          imdb_score        gross
# movie_title
# John Carter                                     6.6   73058679.0
# Spider-Man 3                                    6.2  336530303.0
# Tangled                                         7.8  200807262.0
# Avengers: Age of Ultron                         7.5  458991599.0
# Harry Potter and the Half-Blood Prince          7.5  301956980.0

# %% [markdown]
# ## Conditional Selection.

# %% [markdown]
# ### FInding the movies which were made in 2015.

# %%
condition = (sub['title_year'] == 2015)
condition.head(10)

#This method is quite messy.
# Out:
# movie_title
# Avatar                                                     False
# Pirates of the Caribbean: At World's End                   False
# Spectre                                                     True
# The Dark Knight Rises                                      False
# Star Wars: Episode VII - The Force Awakens                 False
# John Carter                                                False
# Spider-Man 3                                               False
# Tangled                                                    False
# Avengers: Age of Ultron                                     True
# Harry Potter and the Half-Blood Prince                     False
# Name: title_year, dtype: bool

# %%
# Filtering out all the movies which were not made in 2015.

sub[ sub['title_year'] == 2015]   

#Read like "Select ALL from 'sub' where 'sub title_year' equals 2015."
# Out:
#                           title_year            actor_1_name  \
# movie_title
# Spectre                       2015.0         Christoph Waltz
# Avengers: Age of Ultron       2015.0         Chris Hemsworth
# Jurassic World                2015.0     Bryce Dallas Howard
# Furious 7                     2015.0           Jason Statham
# The Good Dinosaur             2015.0            A.J. Buckley
# ...                              ...                     ...
# The Gallows                   2015.0           Pfeifer Brown
# Queen Crab                    2015.0  Michelle Simone Miller
# Counting                      2015.0                     NaN
# Dutch Kills                   2015.0             Tjasa Ferme
# Exeter                        2015.0         Ashley Tramonte
#
#                                                              genres  \
# movie_title
# Spectre                                   Action|Adventure|Thriller
# Avengers: Age of Ultron                     Action|Adventure|Sci-Fi
# Jurassic World                     Action|Adventure|Sci-Fi|Thriller
# Furious 7                                     Action|Crime|Thriller
# The Good Dinosaur         Adventure|Animation|Comedy|Family|Fantasy
# ...                                                             ...
# The Gallows                                         Horror|Thriller
# Queen Crab                                   Action|Sci-Fi|Thriller
# Counting                                                Documentary
# Dutch Kills                                    Crime|Drama|Thriller
# Exeter                                      Horror|Mystery|Thriller
#
#                           imdb_score        gross
# movie_title
# Spectre                          6.8  200074175.0
# Avengers: Age of Ultron          7.5  458991599.0
# Jurassic World                   7.0  652177271.0
# Furious 7                        7.2  350034110.0
# The Good Dinosaur                6.8  123070338.0
# ...                              ...          ...
# The Gallows                      4.2   22757819.0
# Queen Crab                       4.5          NaN
# Counting                         6.0          NaN
# Dutch Kills                      4.8          NaN
# Exeter                           4.6          NaN
#
# [226 rows x 5 columns]

# %% [markdown]
# ### Finding the movies which have rating at least 8.5.

# %%
good_movies = sub[sub['imdb_score'] >= 8.5]
good_movies.sort_values(by = 'imdb_score', ascending = False)['imdb_score']
# Out:
# movie_title
# Towering Inferno                 9.5
# The Shawshank Redemption         9.3
# The Godfather                    9.2
# Dekalog                          9.1
# Dekalog                          9.1
#                                 ...
# Entourage                        8.5
# Raiders of the Lost Ark          8.5
# Psycho                           8.5
# Alien                            8.5
# Back to the Future               8.5
# Name: imdb_score, Length: 73, dtype: float64

# %% [markdown]
# - Using Logical operators like __|__ for "OR" and __&__ for "AND".

# %% [markdown]
# ### Finding top 10 movies which were released in 2016 and have rating greater than or equal to 8.5.

# %%
good_movies_2015 = sub[ (sub['imdb_score'] >= 8.5) & (sub['title_year'] == 2016) ]
good_movies_2015.sort_values(by = 'imdb_score', ascending = False)[ ['imdb_score', 'title_year'] ].head(10)
# Out:
#                               imdb_score  title_year
# movie_title
# Kickboxer: Vengeance                 9.1      2016.0
# A Beginner's Guide to Snuff          8.7      2016.0
# Airlift                              8.5      2016.0

# %% [markdown]
# ## Applying functions into the dataframe.

# %% [markdown]
# - We will categorize the movies as follows:
# - Movies with rating
#     - greater than or equal to 8.0 is '__good__'.
#     - greater than or equal to 7.0 and less than 8.0 is '__mediocre__'.
#     - less than 7.0 is '**bad**'.

# %%
def rating_func(score):
    if score >=8.0:
        return 'Good'
    elif score >= 7.0 and score < 8.0:
        return 'Mediocre'
    elif score <7.0:
        return 'Bad'

# %%
movies['rating_category'] = movies['imdb_score'].apply(rating_func)

movies[['imdb_score', 'rating_category']].head(10)
# Out:
#                                                     imdb_score rating_category
# movie_title
# Avatar                                                     7.9        Mediocre
# Pirates of the Caribbean: At World's End                   7.1        Mediocre
# Spectre                                                    6.8             Bad
# The Dark Knight Rises                                      8.5            Good
# Star Wars: Episode VII - The Force Awakens     ...         7.1        Mediocre
# John Carter                                                6.6             Bad
# Spider-Man 3                                               6.2             Bad
# Tangled                                                    7.8        Mediocre
# Avengers: Age of Ultron                                    7.5        Mediocre
# Harry Potter and the Half-Blood Prince                     7.5        Mediocre

# %% [markdown]
# ### End of Chapter.

# %% [markdown]
# #### Next: plotting tips using seaborn and matplotlib.

# %% [markdown]
# #### Prepared by: Sagun Shakya
#     - GITAM Institute of Science
